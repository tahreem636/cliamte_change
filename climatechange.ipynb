# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/cliamte_change/blob/main/climatechange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_CONFIG_DIR']='/CONTENT/'

# %%
# !kaggle datasets download -d waqi786/climate-change-impact-on-agriculture
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/waqi786/climate-change-impact-on-agriculture
# License(s): apache-2.0
# ...
#   0% 0.00/327k [00:00<?, ?B/s]
# 100% 327k/327k [00:00<00:00, 54.9MB/s]

# %%
import pandas as pd
df = pd.read_csv('/content/climate-change-impact-on-agriculture.zip')
df
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
# !kaggle datasets download -d prokshitha/crop-recommendation-dataset
# Out:
# 403 - Forbidden - Permission 'datasets.get' was denied

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  climate-change-impact-on-agriculture.zip
#   inflating: climate_change_impact_on_agriculture_2024.csv

# %%
df1=pd.read_csv('climate_change_impact_on_agriculture_2024.csv')
df1.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...
